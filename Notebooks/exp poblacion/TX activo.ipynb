# %% [markdown]
# # Exploración Transacciones Activo

# %%
import pandas as pd
import numpy as np


pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',2000)

# %%
path = "/mnt/s3-refined-popular/data_orig/transacciones/tarjeta-credito/"

data = pd.read_csv(path+"transacciones_tarjeta-credito_repgesco-masterfile_M202002.csv", sep="|", encoding="utf-8", 
                  dtype={'CONT_ID':str})
print(data.shape)
data.head()
# Out:
# (3930530, 32)
#   TIPO_ID  TIPO_ID_HOMOL             CONT_ID  IDENTIFICACION_CLIENTE  \
# 0      03        1000007  641952296631718001                     NaN
# 1      03        1000007  641952296631718001                     NaN
# 2      03        1000007  641952296631718001                     NaN
# 3      03        1000007  641952296631718001                     NaN
# 4      03        1000007  641952296631718001                     NaN
#
#             NRO_CUENTA    NUMERO_TARJETA     BIN            COD_UNICO_TRX  \
# 0  4544054303449224175  454405******3667  454405  19999999980228997349130
# 1  4544054303449224175  454405******3667  454405  10000007300228997349120
# 2  4544054303449224175  454405******3667  454405  10000007300228997349100
# 3  4544054303449224175  454405******3667  454405  VT200480355000010005478
# 4  4544054303449224175  454405******3667  454405  10000007300228997349150
#
#                             DESCRIPCION_TRX FECHA_COMPROBANTE FECHA_PROCESO  \
# ...

# %%
data.describe(include='all')
# Out:
#         TIPO_ID  TIPO_ID_HOMOL             CONT_ID  IDENTIFICACION_CLIENTE  \
# count   3930530   3.930530e+06             3261546                     0.0
# unique        9            NaN              199544                     NaN
# top          CC            NaN  149955716548294702                     NaN
# freq    2909584            NaN                1231                     NaN
# mean        NaN   1.000003e+06                 NaN                     NaN
# std         NaN   1.498777e-01                 NaN                     NaN
# min         NaN   1.000001e+06                 NaN                     NaN
# 25%         NaN   1.000003e+06                 NaN                     NaN
# 50%         NaN   1.000003e+06                 NaN                     NaN
# 75%         NaN   1.000003e+06                 NaN                     NaN
# max         NaN   1.000007e+06                 NaN                     NaN
#
#           NRO_CUENTA    NUMERO_TARJETA      BIN    COD_UNICO_TRX  \
# ...

# %%
data[data['CONT_ID']=='103356585843870702']
# Out:
#         TIPO_ID  TIPO_ID_HOMOL             CONT_ID  IDENTIFICACION_CLIENTE  \
# 1189904      CC        1000003  103356585843870702                     NaN
# 1189905      CC        1000003  103356585843870702                     NaN
# 1189906      CC        1000003  103356585843870702                     NaN
# 1189907      CC        1000003  103356585843870702                     NaN
# 1189908      CC        1000003  103356585843870702                     NaN
# 1189909      CC        1000003  103356585843870702                     NaN
# 1189910      CC        1000003  103356585843870702                     NaN
# 1189911      CC        1000003  103356585843870702                     NaN
# 1189912      CC        1000003  103356585843870702                     NaN
# 1189913      CC        1000003  103356585843870702                     NaN
# 1189914      CC        1000003  103356585843870702                     NaN
# ...
