# %% [markdown]
# ## Process filtering

# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)

# %%
import s3fs
import pyarrow as pa
import pyarrow.parquet as pq

def spark_read_parquet(s3_url: str, **args):
    fs = s3fs.S3FileSystem()
    # Leyendo base
    dataset = pq.ParquetDataset(s3_url, filesystem=fs)
    table = dataset.read()
    dataframe = table.to_pandas()

    del dataset, table

    return dataframe

fs = s3fs.S3FileSystem()

# %%
"""
MODULE: processing_filtering
This script extracts activos information from the activos file
Steps:
1. Get activos file
2. Get the needed columns and rows from activos file including the needed historical period
3. Create additional columns
"""

def processing_filtering(input_paths_activos):
    """Pending docstring"""
    # 1. Get filter file
    ids_final = get_filtering_file(input_paths_activos)
    print('get_filtering_file')
    # 2. Get demog file
    data_demog = get_demog_file(path)
    print('get_demog_file')
    # 3. Join between 
    ids_final2 = pd.merge(ids_final,data_demog[['id_cliente','id_numero_cliente','id_tp_cd']], on='id_cliente', how='left')
    print('ids_final_df')
    print('filtering_df created successfully')

    return ids_final2


def get_filtering_file(input_path):
    """ Gets the input_path to the activos file, drops some not useful columns
     and outputs a DataFrame
    :param input_path to activos file location
    :return: DataFrame
    """
    
    mes = '01'  ### REVISAR!!!!
    anio = '2021'   ### REVISAR!!!!
    
    filtering_file_path = input_path
    filtering = spark_read_parquet(filtering_file_path)

    filtering.rename(columns=lambda x: x.lower(), inplace=True)
    
    # Filter and casting variables
    filtering = filtering[filtering['id_cliente'].notnull()]
    filtering['id_cliente'] = filtering['id_cliente'].astype('int')
    
    ids = filtering.loc[~filtering['ds_estado_actual'].isin(['Cancelada','Castigado']),'id_cliente'].unique()
    ids_final = pd.DataFrame({'id_cliente':ids})
    ids_final['fecha_camp'] = int(anio+mes)  ### REVISAR!!!!

    return ids_final


def get_demog_file(path):
    """ Gets the input_path to the activos file, drops some not useful columns
     and outputs a DataFrame
    :param input_path to activos file location
    :return: DataFrame
    """

    # read the new table
    data_demog = spark_read_parquet(path)
    data_demog = data_demog[data_demog['ref_num'].str.isdigit()]

    # Join cedula, typeid and casting variables
    data_demog = data_demog.rename(columns={'cont_id':'id_cliente',
                                       'ref_num':'id_numero_cliente'})
    data_demog['id_tp_cd'] = data_demog['id_tp_cd'].astype('str')
    
    # Drop duplicates and casting variables
    data_demog = data_demog.drop_duplicates(subset=['id_tp_cd', 'id_numero_cliente'], keep='first')
    data_demog['id_cliente'] = data_demog['id_cliente'].fillna('-99').astype(np.int64)

    return data_demog

# %%
mes = '01'
anio = '2021'
input_paths_activos = 's3://data-bpop-dev-sandbox/estandarizado/productos/libranzas/productos_libranzas_dwh_M'+anio+mes
path = 's3://data-bpop-dev-sandbox/estandarizado/clientes/identificacion/clientes_identificacion_mdm_D20210218'

ids_final2 = processing_filtering(input_paths_activos)

print(ids_final2.shape)
ids_final2.head()
# Out:
# /home/jupyter/anaconda3/lib/python3.7/site-packages/pyarrow/pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels
# get_filtering_file
# get_demog_file
# ids_final_df
# filtering_df created successfully
# (305273, 4)
#            id_cliente  fecha_camp id_numero_cliente id_tp_cd
# 0  102652295880533801      202101          13544804  1000003
# 1  102652294446682301      202101           2485304  1000003
# 2  102652295151150201      202101           6880226  1000003
# 3  102652314595088801      202101          41311613  1000003
# 4  102652308842687701      202101          36695801  1000003

# %%
import boto3

# %%
def list_files(s3_path):
    """
    Autor: ADL
    Email: ADL
    Descripcion; Función para ver los elementos que hay en una ruta determinada.
    Parámetros: texto con la ruta de interés
    Retorno: Listado de los elementos que se encuentra en la ruta determinada.
    """
    s3 = boto3.resource('s3')
    bucket = s3_path.split('//')[1].split('/')[0]
    my_bucket = s3.Bucket(bucket)
    prefix = '/'.join(s3_path.split('//')[1].split('/')[1:])
    n_sub = len(prefix.split('/'))
    list_obj = []
    for object_summary in my_bucket.objects.filter(Prefix=prefix):
        obj_x = object_summary.key.split('/')[n_sub - 1]
        if not obj_x in list_obj:
            list_obj.append(obj_x)
    return(list_obj)

# %%
list_files('s3://data-bpop-dev-sandbox/estandarizado/productos/activo-tarjeta-credito-nueva/')
# Out:
# ['productos_activo-tarjeta-credito-nueva_masterfile_D20200511',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200512',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200513',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200514',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200518',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200519',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200520',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200521',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200522',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200526',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200527',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200528',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200529',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200601',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200602',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200603',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200604',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200605',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200608',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200609',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200611',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200612',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200616',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200617',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200618',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200619',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200623',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200624',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200625',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200626',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200627',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200630',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200702',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200703',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200704',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200705',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200706',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200707',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200708',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200709',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200710',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200711',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200712',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200713',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200714',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200715',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200716',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200717',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200718',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200719',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200720',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200721',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200722',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200723',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200724',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200725',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200726',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200727',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200728',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200729',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200730',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200731',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200801',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200802',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200803',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200804',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200805',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200806',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200807',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200808',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200809',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200810',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200811',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200812',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200813',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200814',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200815',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200816',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200817',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200818',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200819',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200820',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200821',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200822',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200823',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200824',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200825',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200826',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200827',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200828',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200829',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200830',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200831',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200901',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200902',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200903',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200904',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200905',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200906',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200908',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200909',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200910',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200911',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200912',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200913',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200914',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200915',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200917',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200918',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200919',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200920',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200921',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200922',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200923',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200924',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200925',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200926',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200927',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200928',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200929',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20200930',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201001',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201002',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201003',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201004',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201005',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201006',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201007',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201008',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201009',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201010',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201011',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201012',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201013',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201014',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201015',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201016',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201017',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201018',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201019',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201020',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201021',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201022',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201023',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201024',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201025',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201026',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201027',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201028',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201029',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201030',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201031',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201101',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201102',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201103',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201104',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201105',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201106',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201108',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201109',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201110',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201111',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201112',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201113',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201114',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201115',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201116',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201117',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201118',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201119',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201120',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201121',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201122',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201123',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201124',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201125',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201126',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201127',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201128',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201129',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201130',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201201',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201202',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201203',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201204',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201205',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201206',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201207',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201208',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201209',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201210',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201211',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201213',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201214',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201215',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201216',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201217',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201218',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201219',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201220',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201221',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201222',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201223',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201224',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201225',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201226',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201227',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201228',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201229',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201230',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20201231',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210101',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210102',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210103',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210104',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210105',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210106',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210107',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210108',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210109',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210110',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210111',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210112',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210113',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210114',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210115',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210116',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210117',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210118',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210119',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210120',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210121',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210122',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210123',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210124',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210125',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210126',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210127',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210128',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210129',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210130',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210131',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210201',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210202',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210203',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210204',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210205',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210206',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210207',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210208',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210209',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210210',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210211',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210212',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210214',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210215',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210216',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210217',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210218',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210219',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210220',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210221',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210222',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210223',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210224',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210225',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210226',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210227',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210228',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210301',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210302',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210303',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210304',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210305',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210306',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210307',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210308',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210309',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210310',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210311',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210312',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210313',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210314',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210315',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210316',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210317',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210318',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210319',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210320',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210321',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210322',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210323',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210324',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210325',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210326',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210327',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210328',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210329',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210330',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210331',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210401',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210402',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210403',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210404',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210405',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210406',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210407',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210408',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210409',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210410',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210411',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210412',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210413',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210414',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210415',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210416',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210417',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210418',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210419',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210420',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210421',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210422',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210423',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210424',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210425',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210426',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210427',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210428',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210429',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210430',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210501',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210502',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210503',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210504',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210505',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210506',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210507',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210508',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210509',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210510',
#  'productos_activo-tarjeta-credito-nueva_masterfile_D20210511']
