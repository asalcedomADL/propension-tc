# %%
import pandas as pd 
import numpy as np

# %%
lista_2019_2=[]

# %%
prueba=pd.read_csv("s3://adl-refined-dev-popular/data_orig/productos/activo/productos_activo_sarc_M202002.csv",delimiter="|",dtype={'ID_CLIENTE':object,'NROOBLIG':object})
prueba.columns = [x.lower() for x in prueba.columns]
prueba['fecha']='202002'
lista_2019_2.append(prueba)

# %%
prueba.head()
# Out:
#    tipo_ident  sk_cliente    id_cliente tipo_producto  lineacredi  \
# 0         1.0   1491360.0  4.219523e+17            LB          66
# 1         1.0   3314951.0  9.627523e+17            LB          66
# 2         1.0   1037664.0  3.030523e+17            LB          66
# 3         1.0   2219064.0  6.366523e+17            LB          66
# 4         1.0   2630128.0  7.969523e+17            LB          66
#
#          nrooblig  cod_ofic  plazo  cuota_paga      fecdes  ...      fecven  \
# 0  16003240000103       160     92        70.0  2014-02-19  ...  2021-10-05
# 1   2903230000141        29     92        75.0  2013-09-30  ...  2021-05-05
# 2   4203230000876        42    120         9.0  2019-03-19  ...  2029-06-05
# 3  35103230000103       351     92        55.0  2015-05-21  ...  2023-01-05
# 4  49403670000144       494    120         7.0  2019-05-28  ...  2029-08-05
#
#    vlr_desemb  sal_capita  vlr_cuota  tasint_cte  tasint_mor  dias_morak  \
# 0  19500000.0   8428883.0   483279.0       19.42        28.1           0
# 1  70900000.0  21199047.0  1420831.0       19.42        28.1           0
# 2  12500000.0  12331752.0   330514.0       20.12        28.1           0
# 3  19000000.0  12615030.0   523109.0       19.42        28.1           0
# 4  37234000.0  36731317.0   869918.0       15.25        28.1           0
#
#    estado calif_cart   fecha
# 0  ACTIVO          A  202001
# 1  ACTIVO          A  202001
# 2  ACTIVO          A  202001
# 3  ACTIVO          A  202001
# 4  ACTIVO          A  202001
#
# [5 rows x 21 columns]

# %%
prueba.shape
# Out:
# (573550, 21)

# %%
prueba=pd.read_csv("s3://adl-refined-dev-popular/data_orig/productos/activo/productos_activo_sarc_M202003.csv",delimiter="|",dtype={'id_cliente':object,'nrooblig':object})
prueba.columns = [x.lower() for x in prueba.columns]
prueba['fecha']='202003'
lista_2019_2.append(prueba)

prueba=pd.read_csv("s3://adl-refined-dev-popular/data_orig/productos/activo/productos_activo_sarc_M202004.csv",delimiter=";",dtype={'ID_CLIENTE':object,'NROOBLIG':object})
prueba.columns = [x.lower() for x in prueba.columns]
prueba['fecha']='202004'
lista_2019_2.append(prueba)

prueba=pd.read_csv("s3://adl-refined-dev-popular/data_orig/productos/activo/productos_activo_sarc_M202005.csv",delimiter=";",dtype={'ID_CLIENTE':object,'NROOBLIG':object})
prueba.columns = [x.lower() for x in prueba.columns]
prueba['fecha']='202005'
lista_2019_2.append(prueba)

frame_2019_2=pd.concat(lista_2019_2)    
frame_total=frame_2019_2.reset_index()
