# %%
########## Cargando paquetes ##########
import pandas as pd
import numpy as np
import pickle
import datetime
import os
import gc
import s3fs
import pyarrow.parquet as pq


pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',400)

# %% [markdown]
# # Cargando Data MKD

# %%
path = 's3://data-bpop-dev-sandbox-de/campana_mkd/click_to_call/Usuarios_ClicToCall_H20200901_20201031_3.csv'

data_mkd = pd.read_csv(path,encoding='latin-1',sep='|')

print(data_mkd.shape)
data_mkd.head()
# Out:
# (621, 25)
#         fecha        canal    cedula  tipo_identificacion       grupo_prob  \
# 0  2020-09-01  autogestion  64702825                    1  grupo_prob_baja
# 1  2020-09-01      oficina  16480931                    1  grupo_prob_baja
# 2  2020-09-01      oficina  41540048                    1  grupo_prob_baja
# 3  2020-09-01      oficina   8278599                    1  grupo_prob_alta
# 4  2020-09-02  autogestion  31578570                    1  grupo_prob_alta
#
#           segmento     score  decil  edad ingreso_aplicacion  \
# 0    seg_perfilado  0.000028    5.0   NaN                 SI
# 1    seg_perfilado  0.000059    4.0  63.0                 SI
# 2  seg_preaprobado  0.011913    1.0  70.0                 SI
# 3  seg_preaprobado  0.080986    5.0  73.0                 SI
# 4    seg_perfilado  0.000167    3.0  39.0                 SI
#
#   pasa_listas_restrictivas mensaje_listas_restrictivas pasa_envio_otp  \
# ...

# %% [markdown]
# ### Guardando data

# %%
path = '/mnt/work/CU_adquisicionTC/objects/Usuarios_ClicToCall_H20200901_20201031_3.csv'

data_mkd.to_csv(path,encoding='utf-8',sep='|', index=False)
