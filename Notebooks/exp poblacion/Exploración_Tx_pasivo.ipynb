# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas_profiling
import os
pd.set_option('display.max_columns',None)

# %%
# Changing path
os.chdir('/../../../mnt') 
# Transacction Path
input_PATH = 's3-refined-popular/data_orig/transacciones/pasivo/'
output_PATH = 's3-refined/old/Fraude/Transacciones/'

# %%
## Reading file
file_name_201812 = os.path.join(input_PATH,'data_tx_pasivo_201812')

# %%
file_name_201812 = os.path.join(input_PATH,'transacciones_pasivo_aaatr_M201812.csv')

# %%
data_tx_pas = pd.read_csv(file_name_201812,sep=';',encoding='latin-1')#, parse_dates=dates)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-9-6ff123457ace> in <module>
# ----> 1 data_tx_pas = pd.read_csv(file_name_201812,sep=';',encoding='latin-1')#, parse_dates=dates)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
## Reading file
file_name_201909 = os.path.join(input_PATH,'transacciones_pasivo_aaatr_M201909.csv')
#file_name_201910 = os.path.join(input_PATH,'transacciones_pasivo_aaatr_M201910.csv')
#file_name_201911 = os.path.join(input_PATH,'transacciones_pasivo_aaatr_M201911.csv')

#dates = ['FECHA_COMPROBANTE','FECHA_PROCESO','FECHA_PERIODO']

data_tx_pas_201909 = pd.read_csv(file_name_201909,sep=';',encoding='latin-1')#, parse_dates=dates)
#data_tx_pas_201910 = pd.read_csv(file_name_201910,sep=';',encoding='latin-1')#, parse_dates=dates)
#data_tx_pas_201911 = pd.read_csv(file_name_201911,sep=';',encoding='latin-1')#, parse_dates=dates)

data_tx_pas = pd.concat([data_tx_pas_201909])#, data_tx_pas_201910, data_tx_pas_201911])
# Out:
# /home/jupyter/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#data_tx_pas.count()/len(data_tx_pas)

# %%
data_tx_pas.head(50)
# Out:
#     SK_CLIENTE          ID_CLIENTE    AAATR_ACO_REFERE   AAATR_ACO_TERCER  \
# 0      2122776  625952294098177301  0067805704          000830101695
# 1      3094489  908752296398913002
# 2      3094489  908752296398913002  06031711  00608000  000017100966
# 3      3094489  908752296398913002                      000017100966
# 4      3094489  908752296398913002                      000017100966
# 5      3094489  908752296398913002                      000017100966
# 6      3094489  908752296398913002  06031711  00623000  000017100966
# 7      3218548  988352296694989501                      000019324342
# 8      3218548  988352296694989501                      000019324342
# 9      3218548  988352296694989501                      000019324342
# 10     3218548  988352296694989501
# 11     3218548  988352296694989501                      000019324342
# 12     3245047  951252299084132801  000150107936        000041380919
# 13      322513  158852298972210701
# ...

# %%
data_tx_pas.shape
# Out:
# (61368127, 53)

# %%
data_tx_pas = data_tx_pas.drop_duplicates()
data_tx_pas.columns = data_tx_pas.columns.str.lower()

print(data_tx_pas.shape)
print(data_tx_pas.columns)
data_tx_pas.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-16-cf1db3ccc36e> in <module>
# ----> 1 data_tx_pas = data_tx_pas.drop_duplicates()
#       2 data_tx_pas.columns = data_tx_pas.columns.str.lower()
#       3
#       4 print(data_tx_pas.shape)
#       5 print(data_tx_pas.columns)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    4907
#    4908         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4909         duplicated = self.duplicated(subset, keep=keep)
#    4910
#    4911         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4967
#    4968         vals = (col.values for name, col in self.items() if name in subset)
# -> 4969         labels, shape = map(list, zip(*map(f, vals)))
#    4970
# ...
